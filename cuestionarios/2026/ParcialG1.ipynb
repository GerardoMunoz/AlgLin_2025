# %% [markdown]
# <a href="https://colab.research.google.com/github/GerardoMunoz/AlgLin_2025/blob/main/cuestionarios/2026/ParcialG1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp

# %%
A=sp.Matrix([[1,-2,3],[4,5,6],[0,-1,1]])
A
# Out:
# Matrix([
# [1, -2, 3],
# [4,  5, 6],
# [0, -1, 1]])

# %%
b=A@sp.Matrix([[1],[2],[3]])

# %% [markdown]
# # Punto 1
# > (40% del parcial)
#
# Resolver el siguiete sistema de ecuaciones dado por la siguiente matriz extendida $$[A:\vec{b}]$$

# %%
A.row_join(b)
# Out:
# Matrix([
# [1, -2, 3,  6],
# [4,  5, 6, 32],
# [0, -1, 1,  1]])

# %% [markdown]
# 1.a Lo primero es encontrar el determinante de la matriz $A=$

# %%
A
# Out:
# Matrix([
# [1, -2, 3],
# [4,  5, 6],
# [0, -1, 1]])

# %% [markdown]
# utilizando cofactores por algún renglon. Se selecciona el último renglón debido a que es el renglón con más ceros.
#
# $$|A|=a_{31}C_{31}+a_{32}C_{32}+a_{33}C_{33}$$
# $$=a_{31}M_{31}-a_{32}M_{32}+a_{33}M_{33}$$
# $$=0-(-1)\begin{vmatrix}1& 3\\4 &6 \end{vmatrix}+(1)\begin{vmatrix}1&-2 \\ 4& 5\end{vmatrix}$$
# $$=0-(-1)(6-12)+(1)(5+8)$$
# $$=-6+13=7$$

# %%
A.det()
# Out:
# 7

# %% [markdown]
# 1.b Ahora se encuentra el determinante de la matriz $Ax=$

# %%
Ax=b.row_join(A[:,1:])
Ax
# Out:
# Matrix([
# [ 6, -2, 3],
# [32,  5, 6],
# [ 1, -1, 1]])

# %% [markdown]
# utilizando cofactores por alguna columna. Se selecciona la segunda columna ya que ninguna tiene ceros (cualquier columna es viable).
#
# $$|A|=a_{12}C_{12}+a_{22}C_{22}+a_{32}C_{32}$$
# $$=a_{12}M_{12}-a_{22}M_{22}+a_{32}M_{32}$$
# $$=-(-2)\begin{vmatrix}32& 6\\1 &1 \end{vmatrix}+5\begin{vmatrix}6& 3\\1 &1 \end{vmatrix}-(-1)\begin{vmatrix}6&3 \\ 32& 6\end{vmatrix}$$
# $$=-(-2)(32-6)+5(6-3)-(-1)(36-96)$$
# $$=52+15-60=7$$
#
# y por lo tanto
#
# $$x=\frac{A_x}{A}=\frac{7}{7}=1$$

# %%
Ax.det(), Ax.det()/A.det()
# Out:
# (7, 1)

# %% [markdown]
# 1.c Ahora se encuentra el determinante de la matriz  Ay=

# %%
Ay=A[:,0].row_join(b).row_join(A[:,2])
Ay
# Out:
# Matrix([
# [1,  6, 3],
# [4, 32, 6],
# [0,  1, 1]])

# %% [markdown]
# utilizando Sarrus.
# $$\left[\begin{matrix}1 & 6 & 3\\4 & 32 & 6\\0 & 1 & 1\end{matrix}\right]\left.\begin{matrix}1 & 6 \\4 & 32 \\0 & 1 \end{matrix}\right.$$
#
# $$|A_y|=32+0+12-0-6-24=14$$
# entonces
#
# $$y=\frac{A_y}{A}=\frac{14}{7}=2$$

# %%
Ay.det(), Ay.det()/A.det()
# Out:
# (14, 2)

# %% [markdown]
# 1.d Ahora se encuentra el determinante de la matriz $A_z=$

# %%
Az=A[:,:2].row_join(b)
Az
# Out:
# Matrix([
# [1, -2,  6],
# [4,  5, 32],
# [0, -1,  1]])

# %% [markdown]
# utilizando la eliminación de renglones de Gauss

# %%
M=Az[:,:] #No afecta el determinante (1)
M
# Out:
# Matrix([
# [1, -2,  6],
# [4,  5, 32],
# [0, -1,  1]])

# %%
M[1,:]-=4*M[0,:] #No afecta el determinante (1)
M
# Out:
# Matrix([
# [1, -2, 6],
# [0, 13, 8],
# [0, -1, 1]])

# %%
M.row_swap(2,1) # Mulptiplica por (-1)

# %%
M[2,:]+=13*M[1,:] #No afecta el determinante (1)(-1)
M
# Out:
# Matrix([
# [1, -2,  6],
# [0, -1,  1],
# [0,  0, 21]])

# %% [markdown]
# Determinante es el cambio de signo debido al intercambio de renglones por la multiplicacion de la diagonal
#
# $$|A_z|=(-1)((1)(-1)(21))=21$$
# $$z=\frac{A_z}{A}=\frac{21}{7}=3$$

# %%
Az.det(), Az.det()/A.det()
# Out:
# (21, 3)

# %% [markdown]
# # Punto 2
# > (20% del parcial)
#
# Calcular P(0.4)

# %%
P0=sp.Matrix([-1,1])
P0
# Out:
# Matrix([
# [-1],
# [ 1]])

# %%
P1=sp.Matrix([1,1])
P1
# Out:
# Matrix([
# [1],
# [1]])

# %%
P2=sp.Matrix([1,0])
P2
# Out:
# Matrix([
# [1],
# [0]])

# %%
t=0.5

# %%
(1-t)**2*P0+2*(1-t)*t*P1+t**2*P2
# Out:
# Matrix([
# [ 0.5],
# [0.75]])

# %% [markdown]
# Cada renglón vale el 50% del punto

# %% [markdown]
# # Punto 3
# > (20% del parcial)
#
# Encuentre el área del triángulo con vértices $A, B, C$

# %%
A=sp.Matrix([1,2,1])
A
# Out:
# Matrix([
# [1],
# [2],
# [1]])

# %%
B=sp.Matrix([2,-1,0])
B
# Out:
# Matrix([
# [ 2],
# [-1],
# [ 0]])

# %%
C=sp.Matrix([1,1,2])
C
# Out:
# Matrix([
# [1],
# [1],
# [2]])

# %%
u=B-A #10% del punto
u
# Out:
# Matrix([
# [ 1],
# [-3],
# [-1]])

# %%
v=C-A #10% del punto
v
# Out:
# Matrix([
# [ 0],
# [-1],
# [ 1]])

# %%
w=u.cross(v) #40% del punto
w
# Out:
# Matrix([
# [-4],
# [-1],
# [-1]])

# %%
w.norm()/2 #40% del punto
# Out:
# 3*sqrt(2)/2

# %%
w.norm().evalf()/2
# Out:
# 2.12132034355964

# %% [markdown]
# # Punto 4
# > (20% del parcial)
#
# Calcule $(A^T@A)^{-1}@A^T$

# %%
B=sp.Matrix([[1,0],[1,1],[0,1]])
B
# Out:
# Matrix([
# [1, 0],
# [1, 1],
# [0, 1]])

# %%
B1=B.T@B
B1 #30% del punto
# Out:
# Matrix([
# [2, 1],
# [1, 2]])

# %%
B2=B1.inv()
B2 #40% del punto
# Out:
# Matrix([
# [ 2/3, -1/3],
# [-1/3,  2/3]])

# %%
B3=B2@B.T
B3 #30% del punto
# Out:
# Matrix([
# [ 2/3, 1/3, -1/3],
# [-1/3, 1/3,  2/3]])

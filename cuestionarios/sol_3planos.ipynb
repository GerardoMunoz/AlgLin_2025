# %% [markdown]
# <a href="https://colab.research.google.com/github/GerardoMunoz/AlgLin_2025/blob/main/cuestionarios/sol_3planos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Encuentre una ecuación vectorial de la recta que pasa por la interseccion de los 3 planos y es perpendicular al primero

# %%
import sympy as sp
A=sp.Matrix([[3,2,1,0],[1,1,-1,1],[4,-6,7,-2]])
M=A[:,:]
M
# Out:
# Matrix([
# [3,  2,  1,  0],
# [1,  1, -1,  1],
# [4, -6,  7, -2]])

# %%
M.row_swap(0, 1)
M
# Out:
# Matrix([
# [1,  1, -1,  1],
# [3,  2,  1,  0],
# [4, -6,  7, -2]])

# %%
M[1,:]+=-3*M[0,:]
M[2,:]+=-4*M[0,:]
M
# Out:
# Matrix([
# [1,   1, -1,  1],
# [0,  -1,  4, -3],
# [0, -10, 11, -6]])

# %%
M[2,:]+=-10*M[1,:]
M
# Out:
# Matrix([
# [1,  1,  -1,  1],
# [0, -1,   4, -3],
# [0,  0, -29, 24]])

# %%
M[2,:]=M[2,:]/-29
M
# Out:
# Matrix([
# [1,  1, -1,      1],
# [0, -1,  4,     -3],
# [0,  0,  1, -24/29]])

# %%
M[1,:]+=-4*M[2,:]
M[0,:]+=M[2,:]
M
# Out:
# Matrix([
# [1,  1, 0,   5/29],
# [0, -1, 0,   9/29],
# [0,  0, 1, -24/29]])

# %%
M[1,:]=-M[1,:]
M
# Out:
# Matrix([
# [1, 1, 0,   5/29],
# [0, 1, 0,  -9/29],
# [0, 0, 1, -24/29]])

# %%
M[0,:]+=-M[1,:]
M
# Out:
# Matrix([
# [1, 0, 0,  14/29],
# [0, 1, 0,  -9/29],
# [0, 0, 1, -24/29]])

# %% [markdown]
# El punto de intersección es $$P=\frac{1}{29}\begin{pmatrix}14\\-9\\-24\end{pmatrix}$$
#
# La dirección de la recta es perpendicular al primer plano, lo cual corresponde al vector formado por sus coeficientes
#
# $$v=\begin{pmatrix}3\\2\\1\end{pmatrix}$$
#
# Por lo tanto la recta solicitada es:
#
#
# $$\begin{pmatrix}x\\y\\z\end{pmatrix}=\frac{1}{29}\begin{pmatrix}14\\-9\\-24\end{pmatrix}+t\begin{pmatrix}3\\2\\1\end{pmatrix}$$
